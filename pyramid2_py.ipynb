# %% [markdown]
# <a href="https://colab.research.google.com/github/Sophie725/Projects_Beginner/blob/main/pyramid2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def inverted_pyramid() -> None:
  for stars in range(5, 0, -1): #range(start, stop, step)
    for star in range(stars):
      print("*", end="")
    print()

# %%
print(inverted_pyramid())
# Out:
# *****
# ****
# ***
# **
# *
# None
