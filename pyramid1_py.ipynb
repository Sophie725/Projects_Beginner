# %% [markdown]
# <a href="https://colab.research.google.com/github/Sophie725/Projects_Beginner/blob/main/pyramid1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for stars in range(5):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
for stars in range(5):
    print("*" * 5)
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for stars in range(1,6):
  print("*" * stars)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for stars in range(1,6):
  for star in range(stars):
    print("*", end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
def make_stars(n: int) -> None: #make a function
  for stars in range(1, n + 1): #repeat to make rows from 1st to 5th
    for star in range(stars): #repeat to make star on each row
      print("*", end="")
    print()

# %%
if __name__ == '__main__':
    N: int = 5
    make_stars(N)
# Out:
# *
# **
# ***
# ****
# *****
