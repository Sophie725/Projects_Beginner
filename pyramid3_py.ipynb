# %% [markdown]
# <a href="https://colab.research.google.com/github/Sophie725/Projects_Beginner/blob/main/pyramid3_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for stars in range (1, 6):
  # type annotations are for 'functions' only not for 'for' statements
  print(" " * (5 - stars) + "*" * stars)
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
def make_right_pyramid(n) -> None:
  for stars in range(1, n+1):
    for star in range(n - stars):
      print(" ", end = "")
    for sta in range(stars):
      print("*", end = "")

    print()

# %%
print(make_right_pyramid(6))
# Out:
#      *
#     **
#    ***
#   ****
#  *****
# ******
# None

# %%
if __name__ == "__main__":
  N = 5
  make_right_pyramid(N)
# Out:
#     *
#    **
#   ***
#  ****
# *****
